# %% [markdown]
# # About
#
# In this programming assignment you will train a classifier to identify type of a particle. There are six particle types: electron, proton, muon, kaon, pion and ghost. Ghost is a particle with other type than the first five or a detector noise.
#
# Different particle types remain different responses in the detector systems or subdetectors. Thre are five systems: tracking system, ring imaging Cherenkov detector (RICH), electromagnetic and hadron calorimeters, and muon system.
#
# ![pid](https://github.com/hse-aml/hadron-collider-machine-learning/blob/master/week2/pic/pid.jpg?raw=1)
#
# You task is to identify a particle type using the responses in the detector systems.
#
# # Attention
#
# Data files you should download from https://github.com/hse-aml/hadron-collider-machine-learning/releases/tag/Week_2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas
import numpy
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
import utils

# %% [markdown]
# # Download data
#
# Download data used to train classifiers.

# %% [markdown]
# ### Read training file

# %%
data = pandas.read_csv('training.csv.gz')

# %%
data.head()
# Out:
#          TrackP  TrackNDoFSubdetector2  ...  RICH_DLLbeMuon  RICH_DLLbeProton
# 0  74791.156263                   15.0  ...   -2.081143e-07        -24.824400
# 1   2738.489989                   15.0  ...    2.771583e+00         -0.648017
# 2   2161.409908                   17.0  ...   -9.990000e+02       -999.000000
# 3  15277.730490                   20.0  ...   -3.070819e+00        -29.291519
# 4   7563.700195                   19.0  ...   -5.373712e+00         23.653087
#
# [5 rows x 50 columns]

# %% [markdown]
# ### List of columns in the samples

# %% [markdown]
# Here, **Spd** stands for Scintillating Pad Detector, **Prs** - Preshower, **Ecal** - electromagnetic calorimeter, **Hcal** - hadronic calorimeter, **Brem** denotes traces of the particles that were deflected by detector.

# %% [markdown]
# - ID - id value for tracks (presents only in the test file for the submitting purposes)
# - Label - string valued observable denoting particle types. Can take values "Electron", "Muon", "Kaon", "Proton", "Pion" and "Ghost". This column is absent in the test file.
# - FlagSpd - flag (0 or 1), if reconstructed track passes through Spd
# - FlagPrs - flag (0 or 1), if reconstructed track passes through Prs
# - FlagBrem - flag (0 or 1), if reconstructed track passes through Brem
# - FlagEcal - flag (0 or 1), if reconstructed track passes through Ecal
# - FlagHcal - flag (0 or 1), if reconstructed track passes through Hcal
# - FlagRICH1 - flag (0 or 1), if reconstructed track passes through the first RICH detector
# - FlagRICH2 - flag (0 or 1), if reconstructed track passes through the second RICH detector
# - FlagMuon - flag (0 or 1), if reconstructed track passes through muon stations (Muon)
# - SpdE - energy deposit associated to the track in the Spd
# - PrsE - energy deposit associated to the track in the Prs
# - EcalE - energy deposit associated to the track in the Hcal
# - HcalE - energy deposit associated to the track in the Hcal
# - PrsDLLbeElectron - delta log-likelihood for a particle candidate to be electron using information from Prs
# - BremDLLbeElectron - delta log-likelihood for a particle candidate to be electron using information from Brem
# - TrackP - particle momentum
# - TrackPt - particle transverse momentum
# - TrackNDoFSubdetector1  - number of degrees of freedom for track fit using hits in the tracking sub-detector1
# - TrackQualitySubdetector1 - chi2 quality of the track fit using hits in the tracking sub-detector1
# - TrackNDoFSubdetector2 - number of degrees of freedom for track fit using hits in the tracking sub-detector2
# - TrackQualitySubdetector2 - chi2 quality of the track fit using hits in the  tracking sub-detector2
# - TrackNDoF - number of degrees of freedom for track fit using hits in all tracking sub-detectors
# - TrackQualityPerNDoF - chi2 quality of the track fit per degree of freedom
# - TrackDistanceToZ - distance between track and z-axis (beam axis)
# - Calo2dFitQuality - quality of the 2d fit of the clusters in the calorimeter
# - Calo3dFitQuality - quality of the 3d fit in the calorimeter with assumption that particle was electron
# - EcalDLLbeElectron - delta log-likelihood for a particle candidate to be electron using information from Ecal
# - EcalDLLbeMuon - delta log-likelihood for a particle candidate to be muon using information from Ecal
# - EcalShowerLongitudinalParameter - longitudinal parameter of Ecal shower
# - HcalDLLbeElectron - delta log-likelihood for a particle candidate to be electron using information from Hcal
# - HcalDLLbeMuon - delta log-likelihood for a particle candidate to be using information from Hcal
# - RICHpFlagElectron - flag (0 or 1) if momentum is greater than threshold for electrons to produce Cherenkov light
# - RICHpFlagProton - flag (0 or 1) if momentum is greater than threshold for protons to produce Cherenkov light
# - RICHpFlagPion - flag (0 or 1) if momentum is greater than threshold for pions to produce Cherenkov light
# - RICHpFlagKaon - flag (0 or 1) if momentum is greater than threshold for kaons to produce Cherenkov light
# - RICHpFlagMuon - flag (0 or 1) if momentum is greater than threshold for muons to produce Cherenkov light
# - RICH_DLLbeBCK  - delta log-likelihood for a particle candidate to be background using information from RICH
# - RICH_DLLbeKaon - delta log-likelihood for a particle candidate to be kaon using information from RICH
# - RICH_DLLbeElectron - delta log-likelihood for a particle candidate to be electron using information from RICH
# - RICH_DLLbeMuon - delta log-likelihood for a particle candidate to be muon using information from RICH
# - RICH_DLLbeProton - delta log-likelihood for a particle candidate to be proton using information from RICH
# - MuonFlag - muon flag (is this track muon) which is determined from muon stations
# - MuonLooseFlag muon flag (is this track muon) which is determined from muon stations using looser criteria
# - MuonLLbeBCK - log-likelihood for a particle candidate to be not muon using information from muon stations
# - MuonLLbeMuon - log-likelihood for a particle candidate to be muon using information from muon stations
# - DLLelectron - delta log-likelihood for a particle candidate to be electron using information from all subdetectors
# - DLLmuon - delta log-likelihood for a particle candidate to be muon using information from all subdetectors
# - DLLkaon - delta log-likelihood for a particle candidate to be kaon using information from all subdetectors
# - DLLproton - delta log-likelihood for a particle candidate to be proton using information from all subdetectors
# - GhostProbability - probability for a particle candidate to be ghost track. This variable is an output of classification model used in the tracking algorithm.

# %% [markdown]
# Delta log-likelihood in the features descriptions means the difference between log-likelihood for the mass hypothesis that a given track is left by some particle (for example, electron) and log-likelihood for the mass hypothesis that a given track is left by a pion (so, DLLpion = 0 and thus we don't have these columns). This is done since most tracks (~80%) are left by pions and in practice we actually need to discriminate other particles from pions. In other words, the null hypothesis is that particle is a pion.

# %% [markdown]
# ### Look at the labels set
#
# The training data contains six classes. Each class corresponds to a particle type. Your task is to predict type of a particle.

# %%
set(data.Label)
# Out:
# {'Electron', 'Ghost', 'Kaon', 'Muon', 'Pion', 'Proton'}

# %% [markdown]
# Convert the particle types into class numbers.

# %%
data['Class'] = utils.get_class_ids(data.Label.values)
set(data.Class)
# Out:
# {0, 1, 2, 3, 4, 5}

# %% [markdown]
# ### Define training features
#
# The following set of features describe particle responses in the detector systems:
#
# ![features](https://github.com/hse-aml/hadron-collider-machine-learning/blob/master/week2/pic/features.jpeg?raw=1)
#
# Also there are several combined features. The full list is following.

# %%
features = list(set(data.columns) - {'Label', 'Class'})
features
# Out:
# ['DLLkaon',
#  'FlagSpd',
#  'EcalE',
#  'RICH_DLLbeElectron',
#  'PrsE',
#  'SpdE',
#  'TrackQualitySubdetector2',
#  'FlagPrs',
#  'PrsDLLbeElectron',
#  'RICH_DLLbeBCK',
#  'TrackPt',
#  'TrackNDoFSubdetector2',
#  'RICH_DLLbeProton',
#  'EcalDLLbeElectron',
#  'TrackNDoF',
#  'RICHpFlagMuon',
#  'MuonFlag',
#  'FlagEcal',
#  'Calo2dFitQuality',
#  'FlagRICH2',
#  'RICHpFlagProton',
#  'FlagBrem',
#  'HcalDLLbeElectron',
#  'TrackQualityPerNDoF',
#  'RICH_DLLbeKaon',
#  'RICHpFlagPion',
#  'EcalShowerLongitudinalParameter',
#  'HcalDLLbeMuon',
#  'DLLelectron',
#  'TrackNDoFSubdetector1',
#  'RICHpFlagElectron',
#  'FlagHcal',
#  'GhostProbability',
#  'RICHpFlagKaon',
#  'TrackDistanceToZ',
#  'MuonLLbeMuon',
#  'FlagMuon',
#  'Calo3dFitQuality',
#  'RICH_DLLbeMuon',
#  'HcalE',
#  'FlagRICH1',
#  'TrackQualitySubdetector1',
#  'DLLproton',
#  'DLLmuon',
#  'EcalDLLbeMuon',
#  'BremDLLbeElectron',
#  'MuonLLbeBCK',
#  'MuonLooseFlag',
#  'TrackP']

# %% [markdown]
# ### Divide training data into 2 parts

# %%
training_data, validation_data = train_test_split(data, random_state=11, train_size=0.90)

# %%
len(training_data), len(validation_data)
# Out:
# (1080000, 120000)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
training_scale = scaler.fit_transform(training_data[features].values)

validation_scale = scaler.transform(validation_data[features].values)

# %% [markdown]
# # Sklearn classifier
#
# On this step your task is to train **Sklearn** classifier to provide lower **log loss** value.
#
#
# TASK: your task is to tune the classifier parameters to achieve the lowest **log loss** value on the validation sample you can.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# %%time 
gb = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50, subsample=0.8, random_state=13,
                                min_samples_leaf=10, max_depth=3)
gb.fit(training_scale, training_data.Class.values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-45174ddb06a8> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'gb = GradientBoostingClassifier(learning_rate=0.1, n_estimators=50, subsample=0.8, random_state=13,\n                                min_samples_leaf=10, max_depth=3)\ngb.fit(training_scale, training_data.Class.values)')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#    1535         n_stages = self._fit_stages(
#    1536             X, y, raw_predictions, sample_weight, self._rng, X_val, y_val,
# -> 1537             sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1538
#    1539         # change shape of arrays after fit (early-stopping or additional ests)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor, X_idx_sorted)
#    1592             raw_predictions = self._fit_stage(
#    1593                 i, X, y, raw_predictions, sample_weight, sample_mask,
# -> 1594                 random_state, X_idx_sorted, X_csc, X_csr)
#    1595
#    1596             # track deviance (= loss)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#    1243             X = X_csr if X_csr is not None else X
#    1244             tree.fit(X, residual, sample_weight=sample_weight,
# -> 1245                      check_input=False, X_idx_sorted=X_idx_sorted)
#    1246
#    1247             # update tree leaves
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1223             sample_weight=sample_weight,
#    1224             check_input=check_input,
# -> 1225             X_idx_sorted=X_idx_sorted)
#    1226         return self
#    1227
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Log loss on the cross validation sample

# %%
# predict each track
proba_gb = gb.predict_proba(validation_scale)

# %%
log_loss(validation_data.Class.values, proba_gb)
# Out:
# 0.6661485197221816

# %% [markdown]
# # Keras neural network
#
# On this step your task is to train **Keras** NN classifier to provide lower **log loss** value.
#
#
# TASK: your task is to tune the classifier parameters to achieve the lowest **log loss** value on the validation sample you can. Data preprocessing may help you to improve your score.

# %%
from keras.layers.core import Dense, Activation
from keras.models import Sequential
from keras.optimizers import Adam
from keras.utils import np_utils

# %%
def nn_model(input_dim):
    model = Sequential()
    model.add(Dense(100, input_dim=input_dim))
    model.add(Activation('relu'))

    model.add(Dense(50))
    model.add(Activation('relu'))

    model.add(Dense(6))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer=Adam())
    return model

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

callback = [EarlyStopping(monitor='val_loss', min_delta=0, patience=4, verbose=0, mode='auto'),
            ModelCheckpoint('output/{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')]

# %%
nn = nn_model(len(features))
nn.fit(training_scale, np_utils.to_categorical(training_data.Class.values),
       validation_data=(validation_scale, np_utils.to_categorical(validation_data.Class.values)),
       epochs=50, verbose=1, batch_size=256, callbacks=callback)
# Out:
# Epoch 1/50
# 4213/4219 [============================>.] - ETA: 0s - loss: 0.7002
# Epoch 00001: val_loss improved from inf to 0.62823, saving model to output/0.6282.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.7001 - val_loss: 0.6282
# Epoch 2/50
# 4207/4219 [============================>.] - ETA: 0s - loss: 0.6154
# Epoch 00002: val_loss improved from 0.62823 to 0.60451, saving model to output/0.6045.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.6154 - val_loss: 0.6045
# Epoch 3/50
# 4211/4219 [============================>.] - ETA: 0s - loss: 0.6032
# Epoch 00003: val_loss improved from 0.60451 to 0.59627, saving model to output/0.5963.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.6032 - val_loss: 0.5963
# Epoch 4/50
# 4211/4219 [============================>.] - ETA: 0s - loss: 0.5970
# Epoch 00004: val_loss improved from 0.59627 to 0.59220, saving model to output/0.5922.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5970 - val_loss: 0.5922
# Epoch 5/50
# 4193/4219 [============================>.] - ETA: 0s - loss: 0.5920
# Epoch 00005: val_loss improved from 0.59220 to 0.59108, saving model to output/0.5911.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5919 - val_loss: 0.5911
# Epoch 6/50
# 4207/4219 [============================>.] - ETA: 0s - loss: 0.5884
# Epoch 00006: val_loss improved from 0.59108 to 0.58818, saving model to output/0.5882.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5884 - val_loss: 0.5882
# Epoch 7/50
# 4214/4219 [============================>.] - ETA: 0s - loss: 0.5859
# Epoch 00007: val_loss improved from 0.58818 to 0.58444, saving model to output/0.5844.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5859 - val_loss: 0.5844
# Epoch 8/50
# 4207/4219 [============================>.] - ETA: 0s - loss: 0.5829
# Epoch 00008: val_loss improved from 0.58444 to 0.58080, saving model to output/0.5808.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5829 - val_loss: 0.5808
# Epoch 9/50
# 4218/4219 [============================>.] - ETA: 0s - loss: 0.5804
# Epoch 00009: val_loss did not improve from 0.58080
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5804 - val_loss: 0.5836
# Epoch 10/50
# 4217/4219 [============================>.] - ETA: 0s - loss: 0.5787
# Epoch 00010: val_loss improved from 0.58080 to 0.57774, saving model to output/0.5777.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5787 - val_loss: 0.5777
# Epoch 11/50
# 4216/4219 [============================>.] - ETA: 0s - loss: 0.5771
# Epoch 00011: val_loss did not improve from 0.57774
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5771 - val_loss: 0.5796
# Epoch 12/50
# 4209/4219 [============================>.] - ETA: 0s - loss: 0.5754
# Epoch 00012: val_loss improved from 0.57774 to 0.57482, saving model to output/0.5748.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5754 - val_loss: 0.5748
# Epoch 13/50
# 4200/4219 [============================>.] - ETA: 0s - loss: 0.5746
# Epoch 00013: val_loss improved from 0.57482 to 0.57390, saving model to output/0.5739.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5744 - val_loss: 0.5739
# Epoch 14/50
# 4197/4219 [============================>.] - ETA: 0s - loss: 0.5735
# Epoch 00014: val_loss did not improve from 0.57390
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5733 - val_loss: 0.5751
# Epoch 15/50
# 4200/4219 [============================>.] - ETA: 0s - loss: 0.5723
# Epoch 00015: val_loss did not improve from 0.57390
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5723 - val_loss: 0.5788
# Epoch 16/50
# 4193/4219 [============================>.] - ETA: 0s - loss: 0.5712
# Epoch 00016: val_loss improved from 0.57390 to 0.57376, saving model to output/0.5738.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5712 - val_loss: 0.5738
# Epoch 17/50
# 4201/4219 [============================>.] - ETA: 0s - loss: 0.5706
# Epoch 00017: val_loss improved from 0.57376 to 0.57242, saving model to output/0.5724.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5706 - val_loss: 0.5724
# Epoch 18/50
# 4206/4219 [============================>.] - ETA: 0s - loss: 0.5699
# Epoch 00018: val_loss improved from 0.57242 to 0.57169, saving model to output/0.5717.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5699 - val_loss: 0.5717
# Epoch 19/50
# 4198/4219 [============================>.] - ETA: 0s - loss: 0.5691
# Epoch 00019: val_loss did not improve from 0.57169
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5691 - val_loss: 0.5722
# Epoch 20/50
# 4214/4219 [============================>.] - ETA: 0s - loss: 0.5685
# Epoch 00020: val_loss improved from 0.57169 to 0.57127, saving model to output/0.5713.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5685 - val_loss: 0.5713
# Epoch 21/50
# 4216/4219 [============================>.] - ETA: 0s - loss: 0.5677
# Epoch 00021: val_loss did not improve from 0.57127
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5677 - val_loss: 0.5727
# Epoch 22/50
# 4206/4219 [============================>.] - ETA: 0s - loss: 0.5675
# Epoch 00022: val_loss did not improve from 0.57127
# 4219/4219 [==============================] - 9s 2ms/step - loss: 0.5675 - val_loss: 0.5716
# Epoch 23/50
# 4206/4219 [============================>.] - ETA: 0s - loss: 0.5667
# Epoch 00023: val_loss improved from 0.57127 to 0.57069, saving model to output/0.5707.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5667 - val_loss: 0.5707
# Epoch 24/50
# 4206/4219 [============================>.] - ETA: 0s - loss: 0.5662
# Epoch 00024: val_loss improved from 0.57069 to 0.56908, saving model to output/0.5691.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5662 - val_loss: 0.5691
# Epoch 25/50
# 4208/4219 [============================>.] - ETA: 0s - loss: 0.5658
# Epoch 00025: val_loss did not improve from 0.56908
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5658 - val_loss: 0.5704
# Epoch 26/50
# 4199/4219 [============================>.] - ETA: 0s - loss: 0.5657
# Epoch 00026: val_loss improved from 0.56908 to 0.56839, saving model to output/0.5684.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5656 - val_loss: 0.5684
# Epoch 27/50
# 4200/4219 [============================>.] - ETA: 0s - loss: 0.5649
# Epoch 00027: val_loss did not improve from 0.56839
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5649 - val_loss: 0.5701
# Epoch 28/50
# 4196/4219 [============================>.] - ETA: 0s - loss: 0.5648
# Epoch 00028: val_loss improved from 0.56839 to 0.56795, saving model to output/0.5679.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5648 - val_loss: 0.5679
# Epoch 29/50
# 4205/4219 [============================>.] - ETA: 0s - loss: 0.5641
# Epoch 00029: val_loss did not improve from 0.56795
# 4219/4219 [==============================] - 9s 2ms/step - loss: 0.5642 - val_loss: 0.5683
# Epoch 30/50
# 4219/4219 [==============================] - ETA: 0s - loss: 0.5640
# Epoch 00030: val_loss improved from 0.56795 to 0.56780, saving model to output/0.5678.hdf5
# 4219/4219 [==============================] - 10s 2ms/step - loss: 0.5640 - val_loss: 0.5678
# Epoch 31/50
# 4212/4219 [============================>.] - ETA: 0s - loss: 0.5639
# Epoch 00031: val_loss did not improve from 0.56780
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5639 - val_loss: 0.5679
# Epoch 32/50
# 4214/4219 [============================>.] - ETA: 0s - loss: 0.5636
# Epoch 00032: val_loss did not improve from 0.56780
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5636 - val_loss: 0.5692
# Epoch 33/50
# 4202/4219 [============================>.] - ETA: 0s - loss: 0.5631
# Epoch 00033: val_loss improved from 0.56780 to 0.56707, saving model to output/0.5671.hdf5
# 4219/4219 [==============================] - 10s 2ms/step - loss: 0.5632 - val_loss: 0.5671
# Epoch 34/50
# 4212/4219 [============================>.] - ETA: 0s - loss: 0.5629
# Epoch 00034: val_loss did not improve from 0.56707
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5629 - val_loss: 0.5673
# Epoch 35/50
# 4200/4219 [============================>.] - ETA: 0s - loss: 0.5627
# Epoch 00035: val_loss did not improve from 0.56707
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5627 - val_loss: 0.5685
# Epoch 36/50
# 4213/4219 [============================>.] - ETA: 0s - loss: 0.5624
# Epoch 00036: val_loss improved from 0.56707 to 0.56656, saving model to output/0.5666.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5624 - val_loss: 0.5666
# Epoch 37/50
# 4207/4219 [============================>.] - ETA: 0s - loss: 0.5620
# Epoch 00037: val_loss improved from 0.56656 to 0.56564, saving model to output/0.5656.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5621 - val_loss: 0.5656
# Epoch 38/50
# 4212/4219 [============================>.] - ETA: 0s - loss: 0.5618
# Epoch 00038: val_loss did not improve from 0.56564
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5618 - val_loss: 0.5660
# Epoch 39/50
# 4211/4219 [============================>.] - ETA: 0s - loss: 0.5617
# Epoch 00039: val_loss did not improve from 0.56564
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5617 - val_loss: 0.5683
# Epoch 40/50
# 4196/4219 [============================>.] - ETA: 0s - loss: 0.5615
# Epoch 00040: val_loss did not improve from 0.56564
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5615 - val_loss: 0.5665
# Epoch 41/50
# 4204/4219 [============================>.] - ETA: 0s - loss: 0.5612
# Epoch 00041: val_loss improved from 0.56564 to 0.56563, saving model to output/0.5656.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5611 - val_loss: 0.5656
# Epoch 42/50
# 4212/4219 [============================>.] - ETA: 0s - loss: 0.5608
# Epoch 00042: val_loss improved from 0.56563 to 0.56371, saving model to output/0.5637.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5608 - val_loss: 0.5637
# Epoch 43/50
# 4193/4219 [============================>.] - ETA: 0s - loss: 0.5608
# Epoch 00043: val_loss did not improve from 0.56371
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5609 - val_loss: 0.5650
# Epoch 44/50
# 4217/4219 [============================>.] - ETA: 0s - loss: 0.5606
# Epoch 00044: val_loss did not improve from 0.56371
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5606 - val_loss: 0.5665
# Epoch 45/50
# 4208/4219 [============================>.] - ETA: 0s - loss: 0.5607
# Epoch 00045: val_loss did not improve from 0.56371
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5607 - val_loss: 0.5653
# Epoch 46/50
# 4215/4219 [============================>.] - ETA: 0s - loss: 0.5603
# Epoch 00046: val_loss improved from 0.56371 to 0.56357, saving model to output/0.5636.hdf5
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5603 - val_loss: 0.5636
# Epoch 47/50
# 4204/4219 [============================>.] - ETA: 0s - loss: 0.5601
# Epoch 00047: val_loss did not improve from 0.56357
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5602 - val_loss: 0.5651
# Epoch 48/50
# 4205/4219 [============================>.] - ETA: 0s - loss: 0.5600
# Epoch 00048: val_loss did not improve from 0.56357
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5600 - val_loss: 0.5666
# Epoch 49/50
# 4199/4219 [============================>.] - ETA: 0s - loss: 0.5598
# Epoch 00049: val_loss did not improve from 0.56357
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5599 - val_loss: 0.5676
# Epoch 50/50
# 4208/4219 [============================>.] - ETA: 0s - loss: 0.5596
# Epoch 00050: val_loss did not improve from 0.56357
# 4219/4219 [==============================] - 8s 2ms/step - loss: 0.5595 - val_loss: 0.5653

# %% [markdown]
# ### Log loss on the cross validation sample

# %%
nn.load_weights('output/0.5636.hdf5')

# %%
# predict each track
proba_nn = nn.predict_proba(validation_scale)

# %%
log_loss(validation_data.Class.values, proba_nn)
# Out:
# 0.5635680758961765

# %% [markdown]
# # Quality metrics
#
# Plot ROC curves and signal efficiency dependece from particle mometum and transverse momentum values.

# %%
proba = proba_nn

# %%
utils.plot_roc_curves(proba, validation_data.Class.values)

# %%
utils.plot_signal_efficiency_on_p(proba, validation_data.Class.values, validation_data.TrackP.values, 60, 50)
plt.show()

# %%
utils.plot_signal_efficiency_on_pt(proba, validation_data.Class.values, validation_data.TrackPt.values, 60, 50)
plt.show()

# %% [markdown]
# # Prepare submission
#
# Select your best classifier and prepare submission file.

# %%
test = pandas.read_csv('test.csv.gz')

# %%
best_model = nn

# %%
# predict test sample

test_scale = scaler.transform(test[features])

submit_proba = best_model.predict_proba(test_scale)
submit_ids = test.ID

# %%
from IPython.display import FileLink
utils.create_solution(submit_ids, submit_proba, filename='submission_file.csv.gz')
# Out:
# /content/submission_file.csv.gz
